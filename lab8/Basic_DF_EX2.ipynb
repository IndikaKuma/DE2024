# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf

sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("Basic_DF_EX2")
sparkConf.set("spark.driver.memory", "2g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")

# create the spark session, which is the entry point to Spark SQL engine.
spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()
df = spark.read.format("csv").option("header", "true") \
       .load("/home/jovyan/data/online-retail-dataset.csv")
df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: string (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- CustomerID: string (nullable = true)
#  |-- Country: string (nullable = true)

# %% [markdown]
# ### What is the average quantity bought by the customer 14769?
#
# **collect** function https://sparkbyexamples.com/pyspark/pyspark-collect/

# %%
from pyspark.sql.functions import col, avg
# 1 
print(df.where(df.CustomerID == "14769").agg(avg(col("Quantity"))).collect())
print(df.where(df.CustomerID == "14769").agg(avg(col("Quantity"))).collect()[0][0])   # first row, first column

# 2
print(df.where(df.CustomerID == "14769").agg({"Quantity": "avg"}).collect()[0][0])
# Out:
# [Row(avg(Quantity)=6.769652650822669)]
# 6.769652650822669
# 6.769652650822669

# %% [markdown]
# ### What is the most occurring word in the items bought by the customers from France?

# %%
from pyspark.sql.functions import explode, split, concat, col, lit, desc

words = df.where(df.Country == "France").select("Description").select(
            explode(
                split(col("Description"), " ")
            ).alias("word")
        )
words.show(10)
ordered_word_count = words.groupby(words.word).count().orderBy(col("count").desc())
ordered_word_count.show(3)
# https://sparkbyexamples.com/pyspark/pyspark-collect/
print(ordered_word_count.collect())
print("\n")
print(ordered_word_count.collect()[1][0])   # second row, first column
# Out:
# +--------+
# |    word|
# +--------+
# |   ALARM|
# |   CLOCK|
# |BAKELIKE|
# |    PINK|
# |   ALARM|
# |   CLOCK|
# |BAKELIKE|
# |     RED|
# |        |
# |   ALARM|
# +--------+
# only showing top 10 rows
#
# +----+-----+
# |word|count|
# +----+-----+
# |    | 2465|
# | RED| 1189|
# | SET| 1128|
# +----+-----+
# only showing top 3 rows
#
# [Row(word='', count=2465), Row(word='RED', count=1189), Row(word='SET', count=1128), Row(word='RETROSPOT', count=1013), Row(word='BAG', count=1006), Row(word='OF', count=958), Row(word='LUNCH', count=645), Row(word='DESIGN', count=600), Row(word='SPACEBOY', count=495), Row(word='BOX', count=483), Row(word='VINTAGE', count=481), Row(word='PINK', count=415), Row(word='PAPER', count=388), Row(word='WOODLAND', count=365), Row(word='TIN', count=356), Row(word='IN', count=352), Row(word='DOLLY', count=349), Row(word='CHILDRENS', count=337), Row(word='PACK', count=337), Row(word='GIRL', count=328), Row(word='MINI', count=317), Row(word='POSTAGE', count=311), Row(word='POLKADOT', count=310), Row(word='CAKE', count=298), Row(word='CASES', count=274), Row(word='JUMBO', count=269), Row(word='PLASTERS', count=261), Row(word='CUTLERY', count=257), Row(word='3', count=234), Row(word='CHRISTMAS', count=226), Row(word='CARD', count=225), Row(word='PARTY', count=219), Row(word='TEA', count=208), Row(word='CIRCUS', count=204), Row(word='PARADE', count=204), Row(word='HEART', count=203), Row(word='6', count=201), Row(word='BLUE', count=200), Row(word='WITH', count=199), Row(word='MUG', count=193), Row(word='CLOCK', count=186), Row(word='4', count=186), Row(word='CHARLOTTE', count=180), Row(word='12', count=179), Row(word='APPLES', count=166), Row(word='LIGHT', count=163), Row(word='SKULL', count=156), Row(word='ALARM', count=156), Row(word='BAKELIKE', count=156), Row(word='NIGHT', count=154), Row(word='SMALL', count=149), Row(word='BIRTHDAY', count=147), Row(word='CUP', count=145), Row(word='BOXES', count=144), Row(word='LONDON', count=142), Row(word='WOODEN', count=139), Row(word='LOVE', count=139), Row(word='ROUND', count=137), Row(word='SPOTTY', count=135), Row(word='SET/6', count=131), Row(word='AND', count=130), Row(word='REGENCY', count=130), Row(word='SNACK', count=123), Row(word='BOWL', count=122), Row(word='GREEN', count=121), Row(word='NAPKINS', count=119), Row(word='WRAP', count=118), Row(word='COLOUR', count=116), Row(word='ASSORTED', count=112), Row(word='MAGNETS', count=110), Row(word='PENCILS', count=109), Row(word='STRAWBERRY', count=108), Row(word='APRON', count=102), Row(word='TOADSTOOL', count=101), Row(word='COFFEE', count=101), Row(word='BAKING', count=100), Row(word='BUNTING', count=100), Row(word='DOILY', count=99), Row(word='ANIMALS', count=98), Row(word='GIFT', count=97), Row(word='CANDLES', count=95), Row(word='I', count=92), Row(word='LED', count=91), Row(word='CUPS', count=90), Row(word='WHITE', count=89), Row(word='CERAMIC', count=89), Row(word='BLACK', count=88), Row(word='UMBRELLA', count=87), Row(word='20', count=87), Row(word='60', count=86), Row(word='APPLE', count=85), Row(word='9', count=85), Row(word='TIER', count=84), Row(word='EGG', count=83), Row(word='PLATES', count=83), Row(word='FAIRY', count=82), Row(word='CHILDS', count=81), Row(word='TUBE', count=81), Row(word='2', count=79), Row(word='TINS', count=78), Row(word='CREAM', count=78), Row(word='RABBIT', count=78), Row(word='METAL', count=77), Row(word='72', count=77), Row(word='JAM', count=76), Row(word='WATER', count=76), Row(word='+', count=74), Row(word='DECORATION', count=74), Row(word='HOME', count=73), Row(word='TRADITIONAL', count=73), Row(word='GARDEN', count=72), Row(word='DOORMAT', count=70), Row(word='COOKIE', count=70), Row(word='36', count=70), Row(word='BALLOONS', count=69), Row(word='PEARS', count=69), Row(word='HOT', count=68), Row(word='PLAYHOUSE', count=68), Row(word="POPPY'S", count=68), Row(word='PLATE', count=68), Row(word='LEAF', count=68), Row(word='BOTTLE', count=67), Row(word='STAND', count=67), Row(word='PANTRY', count=67), Row(word='SET/10', count=67), Row(word='SUKI', count=66), Row(word='TOWELS', count=66), Row(word='OF4', count=65), Row(word='SKULLS', count=65), Row(word='ROSE', count=65), Row(word='LARGE', count=65), Row(word='PIECE', count=64), Row(word='FELTCRAFT', count=63), Row(word='KIT', count=62), Row(word='BEAKER', ...
#
#
# RED

# %%
# Stop the spark context
spark.stop()
