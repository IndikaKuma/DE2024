# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf

sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("Advanced_DF_EX1")
sparkConf.set("spark.driver.memory", "2g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")

# create the spark session, which is the entry point to Spark SQL engine.
spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()
# load data
# Setup hadoop fs configuration for schema gs://
conf = spark.sparkContext._jsc.hadoopConfiguration()
conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
conf.set("fs.AbstractFileSystem.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")

#  Google Storage File Path
gsc_file_path = 'gs://your_bucket/restaurants_geo.csv'  #  use your gcp bucket name. Also upload sales.csv first
# Create data frame
restaurants_geo_df = spark.read.format("csv").option("header", "true").option("delimiter", ";") \
       .load(gsc_file_path)
restaurants_geo_df.printSchema()
restaurants_geo_df.show(5)

restaurants_df = spark.read \
  .format("bigquery") \
  .load("your_project_id.labdataset.restaurants")    # project_id.datatset.tablename. Use your project id
restaurants_df.printSchema()
restaurants_df.show(4)
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- type: string (nullable = true)
#
# +---+--------------------+--------------------+-----------+------------+-----------+
# | id|                name|             address|       city|       phone|       type|
# +---+--------------------+--------------------+-----------+------------+-----------+
# |  1|arnie morton's of...|435 s. la cienega...|los angeles|310/246-1501|   american|
# |  2|arnie morton's of...|435 s. la cienega...|los angeles|310-246-1501|steakhouses|
# |  3|  art's delicatessen| 12224 ventura blvd.|studio city|818/762-1221|   american|
# |  4|          art's deli| 12224 ventura blvd.|studio city|818-762-1221|      delis|
# |  5|       hotel bel-air|701 stone canyon rd.|    bel air|310/472-1211|californian|
# +---+--------------------+--------------------+-----------+------------+-----------+
# only showing top 5 rows
#
# root
#  |-- rid: long (nullable = true)
#  |-- avg_price: double (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- contact: string (nullable = true)
#
# +---+---------+------+-------------------+
# |rid|avg_price|rating|            contact|
# +---+---------+------+-------------------+
# |167|    37.64|   2.0|sdarragh4m@yale.edu|
# |602|    54.41|   2.0|   abatistegp@51.la|
# |289|    52.18|  2.25|  cceely80@hibu.com|
# |338|    98.83|  2.25|mmcerlaine9d@w3.org|
# +---+---------+------+-------------------+
# only showing top 4 rows

# %% [markdown]
# **Give me the contact details of the cheapest restaurant and the most expensive restaurant in each city of USA**

# %%
from pyspark.sql.functions import *
from pyspark.sql import Row, Window

joinExpression = restaurants_geo_df["id"] == restaurants_df['rid']
# default join is the inner join
restaurants_merged = restaurants_geo_df.join(restaurants_df, joinExpression,"left").drop("rid")
restaurants_merged.show(20)
# Rank the resturants in terms of the avg price, per each city. Then, select the best and worst product using ranks
windowdesc = Window.partitionBy(col("city")).orderBy(col("avg_price").desc())
windowasc = Window.partitionBy(col("city")).orderBy(col("avg_price").asc())

restaurants_merged_windowed = restaurants_merged.withColumn("rank_desc", dense_rank().over(windowdesc)).withColumn("rank_asc", dense_rank().over(windowasc))

restaurants_merged_windowed.show(20)
# Get the best and worst-performing restaurants
cheap_expensive_city_table = restaurants_merged_windowed.where((col("rank_desc") == 1) | (col("rank_asc") == 1) ).select("*")
cheap_expensive_city_table.show(20)

cheap_expensive_city_table2 = cheap_expensive_city_table.withColumn("price_category", when(col("rank_desc") == 1, "Most Expensive")
                                                          .otherwise("Cheapest")).select("city", "price_category", "avg_price", "name", "contact", "phone")
cheap_expensive_city_table2.show(20)
# Out:
# +---+--------------------+--------------------+-------------+------------+--------------------+---------+------+--------------------+
# | id|                name|             address|         city|       phone|                type|avg_price|rating|             contact|
# +---+--------------------+--------------------+-------------+------------+--------------------+---------+------+--------------------+
# |  1|arnie morton's of...|435 s. la cienega...|  los angeles|310/246-1501|            american|    58.98|  2.49|lbuckeridge0@indi...|
# |  2|arnie morton's of...|435 s. la cienega...|  los angeles|310-246-1501|         steakhouses|    60.32|  3.69|wstrickland1@goog...|
# |  3|  art's delicatessen| 12224 ventura blvd.|  studio city|818/762-1221|            american|    61.94|  2.57|smiroy2@delicious...|
# |  4|          art's deli| 12224 ventura blvd.|  studio city|818-762-1221|               delis|    77.15|  4.34|radamoli3@google....|
# |  5|       hotel bel-air|701 stone canyon rd.|      bel air|310/472-1211|         californian|    36.39|  3.78|  cwiersma4@etsy.com|
# |  6|       bel-air hotel|701 stone canyon rd.|      bel air|310-472-1211|         californian|    36.03|  3.23|fleteve5@wundergr...|
# |  7|          cafe bizou| 14016 ventura blvd.| sherman oaks|818/788-3536|              french|    31.24|  3.59|bkoschek6@spiegel.de|
# |  8|          cafe bizou| 14016 ventura blvd.| sherman oaks|818-788-3536|       french bistro|    67.21|  3.69|   llansly7@sohu.com|
# |  9|           campanile| 624 s. la brea ave.|  los angeles|213/938-1447|            american|    37.06|  3.03|bmatton8@edublogs...|
# | 10|           campanile| 624 s. la brea ave.|  los angeles|213-938-1447|         californian|    51.98|  2.15|     bdinis9@fda.gov|
# | 11|     chinois on main|       2709 main st.| santa monica|310/392-9025|              french|    46.37|  1.86|   wdaysha@phpbb.com|
# | 12|     chinois on main|       2709 main st.| santa monica|310-392-9025|    pacific new wave|    89.75|  3.16|rbaddileyb@unesco...|
# | 13|              citrus|   6703 melrose ave.|  los angeles|213/857-0034|         californian|    52.08|  0.63|   gcruxtonc@com.com|
# | 14|              citrus|   6703 melrose ave.|  los angeles|213-857-0034|         californian|    74.46|  2.47|lpuncherd@xinhuan...|
# | 15|               fenix|8358 sunset blvd....|    hollywood|213/848-6677|            american|    48.42|  2.14|  lheijnene@narod.ru|
# | 16| fenix at the argyle|   8358 sunset blvd.| w. hollywood|213-848-6677|        french (new)|    48.82|  4.24|  fabreyf@hao123.com|
# | 17|             granita| 23725 w. malibu rd.|       malibu|310/456-0488|         californian|    52.19|  4.96|hchantillong@lulu...|
# | 18|             granita| 23725 w. malibu rd.|       malibu|310-456-0488|         californian|     43.9|  2.58|poscandallh@myspa...|
# | 19|  grill on the alley|     9560 dayton way|  los angeles|310/276-0615|            american|    50.37|  2.44|  lsugarmani@mail.ru|
# | 20|          grill  the|     9560 dayton way|beverly hills|310-276-0615|american (traditi...|    68.07|  2.15| msauvagej@google.it|
# +---+--------------------+--------------------+-------------+------------+--------------------+---------+------+--------------------+
# only showing top 20 rows
#
# +---+--------------------+--------------------+-------+------------+-------------+---------+------+--------------------+---------+--------+
# | id|                name|             address|   city|       phone|         type|avg_price|rating|             contact|rank_desc|rank_asc|
# +---+--------------------+--------------------+-------+------------+-------------+---------+------+--------------------+---------+--------+
# |509|french quarter fo...|923 peachtree st....|atlanta|404/875-2489|     southern|    -2.24|  1.62|cvearnalse4@samsu...|      118|       1|
# |507|dante's down the ...|underground under...|atlanta|404/577-1800|  continental|    -1.17|  3.06|dpickerine2@mozil...|      117|       2|
# |811| johnny rockets (at)|     2970 cobb pkwy.|atlanta|770-955-6068|     american|     5.86|  3.37|ihacquardmi@daily...|      116|       3|
# |824|             riviera|519 e. paces ferr...|atlanta|404-262-7112|mediterranean|    11.72|  3.22| jjansemv@spiegel.de|      115|       4|
# |795|      cafe sunflower|    5975 roswell rd.|atlanta|404-256-1675|  health food|     12.1|  3.25|fbasilottam2@weib...|      114|       5|
# |173| mary mac's tea room|224 ponce de leon...|atlanta|404/876-1800|     southern|    16.98|  4.58|boglevie4s@google...|      113|       6|
# |791|         bistro  the|56 e. andrews dr. nw|atlanta|404-231-5733|french bistro|    17.09| -0.09| iconantly@mysql.com|      112|       7|
# |170|indigo coastal grill|1397 n. highland ...|atlanta|404-876-0676|     eclectic|    17.72|  3.86|arubra4p@sakura.n...|      111|       8|
# |503|          city grill|       50 hurt plaza|atlanta|404/524-2489|international|    17.78|  1.67|cjakovijevicdy@go...|      110|       9|
# |813|     la fonda latina|    4427 roswell rd.|atlanta|404-303-8201|      spanish|    18.95|   3.8|   vhawkermk@com.com|      109|      10|
# |510|  holt bros. bar-b-q|6359 jimmy carter...|atlanta|770/242-3984|     barbecue|    21.16|  3.16|gfenelowe5@paypal...|      108|      11|
# |164|      georgia grille|  2290 peachtree rd.|atlanta|404-352-3517| southwestern|     22.0|  1.97|ltevelov4j@blueho...|      107|      12|
# |157|      buckhead diner|  3073 piedmont road|atlanta|404/262-3336|     american|    23.31|  1.05|   ptripet4c@epa.gov|      106|      13|
# |530|  south city kitchen|  1144 crescent ave.|atlanta|404/873-7358|     southern|    24.33|  3.05|heustaceep@netlog...|      105|      14|
# |508|fat matt's rib shack|1811 piedmont ave...|atlanta|404/607-1622|     barbecue|     25.9|  3.03|rblackborowe3@goo...|      104|      15|
# |534|taste of new orleans|889 w. peachtree st.|atlanta|404/874-5535|     southern|    26.93|  2.29|   bdadeet@google.ru|      103|      16|
# |177|   pano's and paul's|1232 w. paces fer...|atlanta|404/261-3662|international|    28.71|  2.94|lboothebie4w@prwe...|      102|      17|
# |527|           rib ranch|        25 irby ave.|atlanta|404/233-7644|     barbecue|    29.38|  0.84|cshurmanem@earthl...|      101|      18|
# |160|ciboulette restau...|  1529 piedmont ave.|atlanta|404-874-7600| french (new)|    32.73|  4.08| fseyfart4f@1688.com|      100|      19|
# |532|stringer's fish c...|3384 shallowford ...|atlanta|770/458-7145|     southern|    32.89|  3.59|ematejkaer@walmar...|       99|      20|
# +---+--------------------+--------------------+-------+------------+-------------+---------+------+--------------------+---------+--------+
# only showing top 20 rows
#
# +---+--------------------+--------------------+-------------+------------+----------------+---------+------+--------------------+---------+--------+
# | id|                name|             address|         city|       phone|            type|avg_price|rating|             contact|rank_desc|rank_asc|
# +---+--------------------+--------------------+-------------+------------+----------------+---------+------+--------------------+---------+--------+
# |509|french quarter fo...|923 peachtree st....|      atlanta|404/875-2489|        southern|    -2.24|  1.62|cvearnalse4@samsu...|      118|       1|
# |804|          frijoleros|1031 peachtree st...|      atlanta|404-892-8226|         tex-mex|   102.05|  4.57|atravissmb@upenn.edu|        1|     118|
# |  6|       bel-air hotel|701 stone canyon rd.|      bel air|310-472-1211|     californian|    36.03|  3.23|fleteve5@wundergr...|        2|       1|
# |  5|       hotel bel-air|701 stone canyon rd.|      bel air|310/472-1211|     californian|    36.39|  3.78|  cwiersma4@etsy.com|        1|       2|
# |654|brighton coffee shop|   9600 brighton way|beverly hills|310-276-7732|    coffee shops|    17.55|  4.35|zjirucai5@virgini...|        8|       1|
# |649|      belvedere  the|9882 little santa...|beverly hills|310-788-2306|pacific new wave|    77.31|  2.93|   akeani0@webmd.com|        1|       8|
# |709|               taiko|11677 san vicente...|    brentwood|310-207-7782|    noodle shops|    41.96|  3.29|   hcainejo@about.me|        1|       1|
# |749|peter luger steak...|        178 broadway|     brooklyn|718-387-7400|     steakhouses|    25.27|   2.8|pvandaleks@sina.c...|        6|       1|
# |742|           moustache|   405 atlantic ave.|     brooklyn|718-852-5555|  middle eastern|    89.78|  3.78|dlentonkl@netscap...|        1|       6|
# |699|         poquito mas|  2635 w. olive ave.|      burbank|818-563-2252|         mexican|    43.53|  3.54|gawtyje@huffingto...|        1|       1|
# |680|         la cachette|10506 little sant...| century city|310-470-4992|    french (new)|    27.57|  2.06|kpringueriv@paypa...|        1|       1|
# |697|             pho hoa|        642 broadway|    chinatown|213-626-5530|      vietnamese|    40.65|  2.19|    efowleyjc@cbc.ca|        2|       1|
# | 36|philippe the orig...| 1001 n. alameda st.|    chinatown|213-628-3781|      cafeterias|    62.79|  3.38|dcocksedgez@samsu...|        1|       2|
# |832|           zab-e-lee|4837 old national...| college park|404-768-2705|            thai|    75.53|  3.79|cevreuxn3@hugedom...|        1|       1|
# |674|  johnnie's pastrami|4017 s. sepulveda...|  culver city|310-397-6654|           delis|    58.05|  3.78|prumgayip@nationa...|        1|       1|
# |812| kalo's coffee house|  1248 clairmont rd.|      decatur|404-325-3733|    coffeehouses|     3.61|  3.13|   ffoxonmj@ox.ac.uk|        2|       1|
# |822|  rainbow restaurant| 2118 n. decatur rd.|      decatur|404-633-3538|      vegetarian|    23.45|  2.99|mgriffenmt@vistap...|        1|       2|
# |814|lettuce souprise ...|     3525 mall blvd.|       duluth|770-418-9969|      cafeterias|    28.71|  3.39|jmanionml@buzzfee...|        2|       1|
# |809|     indian delights|3675 satellite blvd.|       duluth|100-813-8212|          indian|     84.3|   1.7|gkleinplacmg@inde...|        1|       2|
# |702|    rubin's red hots| 15322 ventura blvd.|       encino|818-905-6515|        hot dogs|    14.13|  5.71|   mmacheljh@dot.gov|        2|       1|
# +---+--------------------+--------------------+-------------+------------+----------------+---------+------+--------------------+---------+--------+
# only showing top 20 rows
#
# +-------------+--------------+---------+--------------------+--------------------+------------+
# |         city|price_category|avg_price|                name|             contact|       phone|
# +-------------+--------------+---------+--------------------+--------------------+------------+
# |      atlanta|      Cheapest|    -2.24|french quarter fo...|cvearnalse4@samsu...|404/875-2489|
# |      atlanta|Most Expensive|   102.05|          frijoleros|atravissmb@upenn.edu|404-892-8226|
# |      bel air|      Cheapest|    36.03|       bel-air hotel|fleteve5@wundergr...|310-472-1211|
# |      bel air|Most Expensive|    36.39|       hotel bel-air|  cwiersma4@etsy.com|310/472-1211|
# |beverly hills|      Cheapest|    17.55|brighton coffee shop|zjirucai5@virgini...|310-276-7732|
# |beverly hills|Most Expensive|    77.31|      belvedere  the|   akeani0@webmd.com|310-788-2306|
# |    brentwood|Most Expensive|    41.96|               taiko|   hcainejo@about.me|310-207-7782|
# |     brooklyn|      Cheapest|    25.27|peter luger steak...|pvandaleks@sina.c...|718-387-7400|
# |     brooklyn|Most Expensive|    89.78|           moustache|dlentonkl@netscap...|718-852-5555|
# |      burbank|Most Expensive|    43.53|         poquito mas|gawtyje@huffingto...|818-563-2252|
# | century city|Most Expensive|    27.57|         la cachette|kpringueriv@paypa...|310-470-4992|
# |    chinatown|      Cheapest|    40.65|             pho hoa|    efowleyjc@cbc.ca|213-626-5530|
# |    chinatown|Most Expensive|    62.79|philippe the orig...|dcocksedgez@samsu...|213-628-3781|
# | college park|Most Expensive|    75.53|           zab-e-lee|cevreuxn3@hugedom...|404-768-2705|
# |  culver city|Most Expensive|    58.05|  johnnie's pastrami|prumgayip@nationa...|310-397-6654|
# |      decatur|      Cheapest|     3.61| kalo's coffee house|   ffoxonmj@ox.ac.uk|404-325-3733|
# |      decatur|Most Expensive|    23.45|  rainbow restaurant|mgriffenmt@vistap...|404-633-3538|
# |       duluth|      Cheapest|    28.71|lettuce souprise ...|jmanionml@buzzfee...|770-418-9969|
# |       duluth|Most Expensive|     84.3|     indian delights|gkleinplacmg@inde...|100-813-8212|
# |       encino|      Cheapest|    14.13|    rubin's red hots|   mmacheljh@dot.gov|818-905-6515|
# +-------------+--------------+---------+--------------------+--------------------+------------+
# only showing top 20 rows

# %% [markdown]
# A useful solution for a common need
# https://stackoverflow.com/questions/34409875/how-to-get-other-columns-when-using-spark-dataframe-groupby

# %%
# Use the Cloud Storage bucket for temporary BigQuery export data the connector uses.
bucket = "your temp bucket"
spark.conf.set('temporaryGcsBucket', bucket)
# Saving the data to BigQuery
cheap_expensive_city_table2.write.format('bigquery') \
  .option('table', 'your_project_id.labdataset.resturants_selection') \
  .mode("overwrite") \
  .save()

# %%
# Stop the spark context
spark.stop()
