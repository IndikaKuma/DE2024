# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import window, col
from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType
from time import sleep

sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("Lab9_8")
sparkConf.set("spark.driver.memory", "2g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")

# create the spark session, which is the entry point to Spark SQL engine.
spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()
# Read the whole dataset as a batch
static = spark.read.json("/home/jovyan/data/activity-data")
dataSchema = static.schema
# Read the dataset as a stream
sdf = spark.readStream.schema(dataSchema).option("maxFilesPerTrigger", 1) \
        .json("/home/jovyan/data/activity-data")
    
historicalAgg = static.groupBy("gt", "model").avg()
# Combine the histotical dataset and the streaming data set
deviceModelStats = sdf.drop("Arrival_Time", "Creation_Time", "Index") \
        .cube("gt", "model").avg() \
        .join(historicalAgg, ["gt", "model"]) \
        .writeStream.queryName("device_counts").format("memory") \
        .outputMode("complete") \
        .start()

for x in range(10):
    spark.sql("SELECT * FROM device_counts").show()
    sleep(10)
# Out:
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.025608492084347567|-0.00865370622082...|-0.07931255272787818|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00211111378466...|0.003161541477127347|0.006135831273853396|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.023266314895782098|-0.03660373344454885| 0.12851069306839294|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.36877579090171...|4.924361915922029E-4|-6.63216907904138...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-5.16108951313128...|6.595482594642077E-4|8.732156086956401E-5|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00451458435114...|-5.02948380941881...|0.009844990415162323|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02728966545882...|-0.01046383734045...|-0.09644315578757234|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022009156867013983|-0.00695552044984...|-0.08324108176894064|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00575165698199...|0.004896581159980394|0.004924508900856233|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.022964470280468614|-0.03670956540108387| 0.13036722313918533|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.07246897160845E-4|3.821254415759556...|-3.55986567238016...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-4.27424353522177...|5.301159281818189E-4| 6.82859295827841E-5|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00675686979840...|0.001080269604178...|0.005789093460175206|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02495418657855565|-0.00980486429696...|-0.10071717765205028|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395502|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153842|  0.1275882097466041|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936|-0.09846155613064732|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395502|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153842|  0.1275882097466041|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936|-0.09846155613064732|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395502|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153842|  0.1275882097466041|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936|-0.09846155613064732|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395502|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153842|  0.1275882097466041|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936|-0.09846155613064732|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+

# %%
# Stop the spark context
spark.stop()
